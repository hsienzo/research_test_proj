# %% [markdown]
# # LIFE on Google Colab — PolitiFact++ (binary MF-vs-MR, LLaMA2-7B)
#
# Faithful reproduction of the paper's setup: binary fake/real over the **LLM pair** (MF=fake, MR=real), with **LLaMA2-7B** as the reconstruction model. End-to-end: **convert → key-sentence extraction → concatenate → features → train**.
#
# **Before you start:**
# 1. Set the Colab runtime to **GPU** — an **A100** is needed for LLaMA2-7B (Runtime → Change runtime type).
# 2. Upload the whole `LIFE` repo (including `dataset/data/`) to your Google Drive, e.g. `MyDrive/LIFE`.
# 3. Edit `PROJECT_DIR` in the path cell below if you put it somewhere else.
# 4. Step 3 uses the **ungated** `NousResearch/Llama-2-7b-hf` mirror by default — no HF token needed. (The official `meta-llama/Llama-2-7b-hf` is gated and requires an approved access request + token.)
#
# Scope: **PolitiFact++** only (~229 LLM-pair articles: 97 fake + 132 real). VLPFN is excluded (its text has no punctuation, so sentence splitting cannot work). GossipCop++ is far heavier; try it only after this works.

# %%
# Confirm a GPU is attached
# !nvidia-smi
# Out:
# Wed Jul  8 01:09:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# <-- change this if you uploaded the repo elsewhere
PROJECT_DIR = '/content/drive/MyDrive/LIFE'
os.chdir(PROJECT_DIR)

POLITIFACT_DIR = f'{PROJECT_DIR}/dataset/data/Fakenews-dataset-main/Fakenews-dataset-main/Dataset/PolitiFact++'

# Paper's binary task: LLM pair only (MF=fake, MR=real), reconstructed with LLaMA2-7B.
OUTPUT_BIN     = f'{PROJECT_DIR}/dataset/output_bin'        # MF_fake.jsonl + MR_true.jsonl
KEY_SENT       = f'{PROJECT_DIR}/dataset/keySentence/important_sentences_top10.jsonl'
BERT_CKPT      = f'{PROJECT_DIR}/dataset/bert_bin.pt'       # fresh extractor for MF-vs-MR
FEATURES_LLAMA = f'{PROJECT_DIR}/dataset/features_llama'
TRAIN_PATH     = f'{PROJECT_DIR}/dataset/train_bin.jsonl'
TEST_PATH      = f'{PROJECT_DIR}/dataset/test_bin.jsonl'

print('cwd:', os.getcwd())
print('PolitiFact++ found:', os.path.isdir(POLITIFACT_DIR))
# Out:
# cwd: /content/drive/MyDrive/LIFE
# PolitiFact++ found: True

# %%
# Install dependencies.
# If the fastNLP import fails at the training step, pin a compatible version:
#   !pip install -q fastNLP==1.0.1
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.7/644.7 kB 36.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.3/217.3 kB 25.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 45.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 6.4 MB/s eta 0:00:00
#   Building wheel for fastNLP (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# textual 6.2.1 requires rich>=13.3.3, but you have rich 11.2.0 which is incompatible.
# bigframes 2.42.0 requires rich<14,>=12.4.4, but you have rich 11.2.0 which is incompatible.
# pymc 5.28.5 requires rich>=13.7.1, but you have rich 11.2.0 which is incompatible.

# %%
# NLTK sentence tokenizer data. 'punkt' gives english.pickle (used by train.py);
# 'punkt_tab' is required by newer nltk's sent_tokenize (used by step 1).
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# ## HuggingFace login (optional)
# Step 3 defaults to the **ungated** `NousResearch/Llama-2-7b-hf` mirror, so **no token is needed — you can skip this cell**. Only run it if you switch Step 3 to the official gated `meta-llama/Llama-2-7b-hf` (which also requires an approved access request).

# %%
# LLaMA-2 is gated on HuggingFace. First accept the license at
# https://huggingface.co/meta-llama/Llama-2-7b-hf, then run this cell and paste an
# access token from https://huggingface.co/settings/tokens
# (or replace with: login(token="hf_xxx")).
from huggingface_hub import login
login()

# %% [markdown]
# ## Step 0 — Convert PolitiFact++ to the binary LLM-pair JSONL
# `--subset llm` emits only `MF_fake.jsonl` (97, fake) and `MR_true.jsonl` (132, real) — the paper's binary task. HF/HR (human-written) are not used.

# %%
# !python dataset/0_convert.py --input_dir "{POLITIFACT_DIR}" --output_dir "{OUTPUT_BIN}" --subset llm

# %% [markdown]
# ## Step 1 — Key-sentence extraction (top-10)
# Trains a **fresh** BERT fake/real classifier on MF-vs-MR (saved to `BERT_CKPT`), then keeps the **top-10** most impactful sentences per article (paper's k for PolitiFact++). This is the slowest step (a forward pass per sentence per article).

# %%
# !python dataset/1_keySentenceExtraction.py --data_dir "{OUTPUT_BIN}" --output_file "{KEY_SENT}" --top_k 10 --model_path "{BERT_CKPT}" --gpu 0

# %% [markdown]
# ## Step 2 — Concatenate key sentences back into the data
# Adds a `sentence` field to each record in `OUTPUT_BIN` by matching on `(id, label)`. **Overwrites the files in `OUTPUT_BIN` in place** — re-run Step 0 first if you need to reset them.

# %%
# !python dataset/2_concate.py --folder_path "{OUTPUT_BIN}" --important_sentences_file "{KEY_SENT}"

# %% [markdown]
# ## Step 3 — Reconstruction probabilities with LLaMA2-7B
# The paper's reconstruction model. A malicious prompt is prepended and LLaMA2-7B's per-token log-likelihoods over the key fragments form the "linguistic fingerprint" features. Loads in bfloat16 (~14 GB; needs the A100) and downloads ~13 GB on first run. Writes one feature JSONL per input file into `FEATURES_LLAMA`.

# %%
# meta-llama/Llama-2-7b-hf is gated (needs Meta approval). NousResearch/Llama-2-7b-hf is an
# ungated mirror of the SAME weights/tokenizer — no token needed. Swap back to the official
# repo if/when your access request is approved.
# !python dataset/3_gen_features_local.py --input_dir "{OUTPUT_BIN}" --output_dir "{FEATURES_LLAMA}" --model NousResearch/Llama-2-7b-hf --scorer llama --dtype bfloat16 --gpu 0

# %% [markdown]
# ## Step 4A — train the classifier (released head: BMES tags + CRF + majority vote)
# Splits `FEATURES_LLAMA` into train/test (seed-0, deterministic) and trains the released Transformer classifier for **50 epochs** on the binary MF-vs-MR task. This head diverges from the paper — it tags tokens with B/M/E/S labels, CRF-decodes them, and recovers the article label by majority vote — so it is the **A-side** of the head A/B. Step 4B below is the paper-faithful head. Paper target for PolitiFact++: **Acc 0.900 / F1 0.882**.

# %%
# !python LIFE_train/train.py \
  --split_dataset \
  --data_path "{FEATURES_LLAMA}" \
  --train_path "{TRAIN_PATH}" \
  --test_path "{TEST_PATH}" \
  --model Transformer \
  --num_train_epochs 50

# %% [markdown]
# ## Step 4B — paper head (sigmoid + BCE, Eq 11–12)
# Same CNN→Transformer trunk, but the head matches the paper: masked mean-pool → one sigmoid probability per article, trained with **binary cross-entropy** (fake=1, real=0) and evaluated directly at article level — no BMES tags, no CRF, no majority vote. Files: `LIFE_train/model_bce.py` + `LIFE_train/train_bce.py` (the originals are untouched and remain the A-side).
#
# **The A/B is fair:** 4A and 4B consume the *same* `FEATURES_LLAMA` and the *same* seed-0 train/test split (`--split_dataset` here regenerates the identical split, so running 4A first is not required). The test set is only ~46 articles (≈2 accuracy points per article), so **re-run this cell with `--seed 1`, `2`, `3`, `4` and report mean ± std**. A-side references: 85.5/80.8 and 83.9/78.2; paper target 90.0/88.2. Checkpoint: `bce_en.pt`.

# %%
# !python LIFE_train/train_bce.py \
  --split_dataset \
  --data_path "{FEATURES_LLAMA}" \
  --train_path "{TRAIN_PATH}" \
  --test_path "{TEST_PATH}" \
  --num_train_epochs 50 \
  --seed 0

# %% [markdown]
# ## Multiclass experiment — 4-class HF / HR / MF / MR (LLaMA2-7B, released CRF/BMES head)
#
# A separate, exploratory run that classifies all **four** PolitiFact++ categories
# (human-fake, human-true, gpt3.5-fake, gpt3.5-true) instead of the paper's binary MF-vs-MR.
# It reuses the released CRF/BMES head via `LIFE_train/train_multi.py` (a copy of `train.py`
# with `en_labels` set to the four classes; `model.py` / `dataloader.py` are imported unchanged).
#
# This needs its own LLaMA2-7B features (the binary `FEATURES_LLAMA` only has MF/MR), so
# Steps 0m–3m re-run the pipeline with `--subset all` into separate `*_multi` paths — nothing
# above is overwritten. Reference: an earlier 4-class run with **gpt2** features scored ~51.7%;
# this swaps in the LLaMA2-7B features.

# %%
# --- 4-class (HF/HR/MF/MR) experiment paths (separate from the binary run above) ---
OUTPUT_MULTI     = f'{PROJECT_DIR}/dataset/output_multi'
KEY_SENT_MULTI   = f'{PROJECT_DIR}/dataset/keySentence/important_sentences_multi_top10.jsonl'
BERT_CKPT_MULTI  = f'{PROJECT_DIR}/dataset/bert_multi.pt'
FEATURES_MULTI   = f'{PROJECT_DIR}/dataset/features_llama_multi'
TRAIN_PATH_MULTI = f'{PROJECT_DIR}/dataset/train_multi.jsonl'
TEST_PATH_MULTI  = f'{PROJECT_DIR}/dataset/test_multi.jsonl'

# %% [markdown]
# ### Step 0m — Convert all four categories
# `--subset all` emits `HF_fake` / `MF_fake` / `HR_true` / `MR_true` JSONL (~520 articles).

# %%
# !python dataset/0_convert.py --input_dir "{POLITIFACT_DIR}" --output_dir "{OUTPUT_MULTI}" --subset all

# %% [markdown]
# ### Step 1m — Key-sentence extraction (top-10)
# Trains a fresh binary BERT (fake = HF+MF, true = HR+MR) and keeps the top-10 sentences per
# article. Slowest step; now over ~520 articles.

# %%
# !python dataset/1_keySentenceExtraction.py --data_dir "{OUTPUT_MULTI}" --output_file "{KEY_SENT_MULTI}" --top_k 10 --model_path "{BERT_CKPT_MULTI}" --gpu 0

# %% [markdown]
# ### Step 2m — Concatenate key sentences
# Adds the `sentence` field to the records in `OUTPUT_MULTI` **in place** — re-run Step 0m to reset.

# %%
# !python dataset/2_concate.py --folder_path "{OUTPUT_MULTI}" --important_sentences_file "{KEY_SENT_MULTI}"

# %% [markdown]
# ### Step 3m — LLaMA2-7B reconstruction features
# Same as the binary Step 3 but over all four files → `FEATURES_MULTI`.

# %%
# !python dataset/3_gen_features_local.py --input_dir "{OUTPUT_MULTI}" --output_dir "{FEATURES_MULTI}" --model NousResearch/Llama-2-7b-hf --scorer llama --dtype bfloat16 --gpu 0

# %% [markdown]
# ### Step 4m — Train the 4-class classifier
# Released CRF/BMES head over 16 BMES tags (4 classes × B/M/E/S), recovered to a 4-class label
# by sentence majority vote. Prints Accuracy / Macro-F1 / per-class precision-recall in the
# class id order printed at startup. Writes `linear_multi_en.pt`.

# %%
# !python LIFE_train/train_multi.py --split_dataset --data_path "{FEATURES_MULTI}" --train_path "{TRAIN_PATH_MULTI}" --test_path "{TEST_PATH_MULTI}" --model Transformer --num_train_epochs 50

# %% [markdown]
# ### Step 4c — Combined-by-veracity binary (fake = HF+MF, real = HR+MR)
# A second side experiment that **pools the human dataset in**: the four categories are
# collapsed to two veracity buckets by label suffix (`LIFE_train/train_combined.py`, a copy of
# `train.py` with a `DataManager` subclass that maps `_fake`→fake / `_true`→true). Released
# CRF/BMES head, sentence majority-vote eval. Per-class P/R prints in the class id order
# (fake=0, true=1) printed at startup.
#
# **Reuses `FEATURES_MULTI`** from the 4-class experiment (features are label-agnostic) — run
# Steps 0m–3m first. `--split_dataset` regenerates the same seed-0 split as Step 4m, so the two
# runs are directly comparable. Reference: a prior combined run scored ~85.2 Acc / 78.4 Macro-F1
# (human-written fakes lack the LLM fingerprint, which drags fake recall down).

# %%
# !python LIFE_train/train_combined.py --split_dataset --data_path "{FEATURES_MULTI}" --train_path "{TRAIN_PATH_MULTI}" --test_path "{TEST_PATH_MULTI}" --model Transformer --num_train_epochs 50

# %% [markdown]
# ## GPT-2 reconstruction model — binary MF-vs-MR (both heads)
#
# Swaps the reconstruction LM from LLaMA2-7B to **GPT-2** on the paper's binary task, run through
# both heads, to isolate the effect of the reconstruction model. No code changes:
# `3_gen_features_local.py` scores with GPT-2 via `--scorer bbpe`, and `train.py` / `train_bce.py`
# are already the binary released / BCE heads.
#
# **Reuses the existing `OUTPUT_BIN`** (the key sentences from the LLaMA binary run's Step 2) — do
# **not** re-run Steps 0–2, so the only difference vs the LLaMA run is the reconstruction LM here.
# (If `OUTPUT_BIN` was reset since, re-run the binary Steps 0–2 first.)
#
# LLaMA baselines: released head ~83.9–85.5 / ~78–80.8; BCE head 86.82 ± 2.157 / 84.48 ± 2.986
# (seeds 0–20).

# %%
# GPT-2 binary paths (separate from the LLaMA binary run's FEATURES_LLAMA / TRAIN_PATH / TEST_PATH)
FEATURES_GPT2_BIN = f'{PROJECT_DIR}/dataset/features_gpt2_bin'
TRAIN_PATH_GPT2   = f'{PROJECT_DIR}/dataset/train_gpt2_bin.jsonl'
TEST_PATH_GPT2    = f'{PROJECT_DIR}/dataset/test_gpt2_bin.jsonl'

# %% [markdown]
# ### Step 3g — GPT-2 reconstruction features
# Scores the same `OUTPUT_BIN` articles with **GPT-2** (`--scorer bbpe`). GPT-2 is small — fast,
# ungated, fits any GPU. Writes `MF_fake.jsonl` + `MR_true.jsonl` into `FEATURES_GPT2_BIN`.

# %%
# !python dataset/3_gen_features_local.py --input_dir "{OUTPUT_BIN}" --output_dir "{FEATURES_GPT2_BIN}" --model gpt2 --scorer bbpe --gpu 0

# %% [markdown]
# ### Step 4A-gpt2 — released CRF/BMES head on GPT-2 features

# %%
# !python LIFE_train/train.py --split_dataset --data_path "{FEATURES_GPT2_BIN}" --train_path "{TRAIN_PATH_GPT2}" --test_path "{TEST_PATH_GPT2}" --model Transformer --num_train_epochs 50

# %% [markdown]
# ### Step 4B-gpt2 — paper BCE head on GPT-2 features
# Same GPT-2 features and the same deterministic seed-0 split as 4A. To match the LLaMA BCE
# headline, re-run with `--seed 1..20` and report mean±std (~46-article test set ≈ 2 pts/article).

# %%
# !python LIFE_train/train_bce.py --split_dataset --data_path "{FEATURES_GPT2_BIN}" --train_path "{TRAIN_PATH_GPT2}" --test_path "{TEST_PATH_GPT2}" --num_train_epochs 50 --seed 0

# %% [markdown]
# ## Qwen2.5-32B reconstruction model — binary MF-vs-MR (4-bit, both heads)
#
# Third reconstruction-model comparison: **Qwen2.5-32B** loaded in **4-bit (nf4)** to fit a
# single 40GB A100. Qwen uses GPT-2-style byte-level BPE, so the existing `--scorer bbpe` path
# handles it; `--load_in_4bit` (new flag in `3_gen_features_local.py`) enables quantization.
# `bitsandbytes` + `accelerate` are already in `requirements.txt`.
#
# **Reuses `OUTPUT_BIN`** (same key sentences as the LLaMA and GPT-2 runs) — only the Step-3
# reconstruction LM changes. Baselines to compare: LLaMA-2-7B (released ~83.9-85.5 / ~78-80.8;
# BCE 86.82 / 84.48 mean); GPT-2 (BCE 83.6 / 78.1).
#
# Notes: the base model `Qwen/Qwen2.5-32B` (not -Instruct) is the right choice for a perplexity
# fingerprint. First run downloads the full bf16 weights (~65GB) then quantizes to ~18-22GB in
# VRAM — the download is the slow part; loading afterward is quick. 4-bit logits differ slightly
# from full precision, so don't mix these features with a non-quantized run in one split.

# %%
# Qwen2.5-32B binary paths (separate from the LLaMA / GPT-2 runs)
FEATURES_QWEN_BIN = f'{PROJECT_DIR}/dataset/features_qwen_bin'
TRAIN_PATH_QWEN   = f'{PROJECT_DIR}/dataset/train_qwen_bin.jsonl'
TEST_PATH_QWEN    = f'{PROJECT_DIR}/dataset/test_qwen_bin.jsonl'

# %% [markdown]
# ### Step 3q — Qwen2.5-32B reconstruction features (4-bit)
# Scores the same `OUTPUT_BIN` articles with Qwen2.5-32B in 4-bit. Do **not** re-run Steps 0-2,
# so the key sentences match the other reconstruction-model runs.

# %%
# !python dataset/3_gen_features_local.py --input_dir "{OUTPUT_BIN}" --output_dir "{FEATURES_QWEN_BIN}" --model Qwen/Qwen2.5-32B --scorer bbpe --load_in_4bit --gpu 0
# Out:
# device: cuda | model: Qwen/Qwen2.5-32B | dtype: bfloat16 | scorer: bbpe | 4bit: True
# config.json: 100% 664/664 [00:00<00:00, 3.41MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json: 100% 7.23k/7.23k [00:00<00:00, 21.6MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 117MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 118MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 129MB/s]
# model.safetensors.index.json: 100% 63.2k/63.2k [00:00<00:00, 140MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...):  68% 40.1G/58.5G [01:54<00:44, 413MB/s]
# Downloading (incomplete total...):  84% 52.3G/62.4G [02:29<00:36, 277MB/s]
# Downloading (incomplete total...):  86% 56.4G/65.5G [02:37<00:15, 600MB/s]
# Downloading (incomplete total...):  93% 61.0G/65.5G [02:49<00:12, 356MB/s]
# Downloading (incomplete total...):  94% 61.5G/65.5G [02:49<00:07, 515MB/s]
# Downloading (incomplete total...):  99% 64.7G/65.5G [02:55<00:01, 579MB/s]
# Downloading (incomplete total...): 100% 65.5G/65.5G [02:59<00:00, 276MB/s]
# Fetching 17 files: 100% 17/17 [03:00<00:00, 10.59s/it]
# Download complete: 100% 65.5G/65.5G [03:00<00:00, 364MB/s]
# Loading weights:   0% 2/771 [00:04<33:58,  2.65s/it]/usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Loading weights: 100% 771/771 [03:23<00:00,  3.80it/s]
# generation_config.json: 100% 138/138 [00:00<00:00, 976kB/s]
# input file:/content/drive/MyDrive/LIFE/dataset/output_bin/MF_fake.jsonl, length:97
#   0% 0/97 [00:00<?, ?it/s]0 57
# 58 122
# 124 202
# 206 280
# 282 306
# 310 350
# 352 436
# 438 484
# 486 538
# 542 578
# 580 648
#   1% 1/97 [00:01<01:57,  1.23s/it]0 57
# 58 122
# 124 158
# 161 197
# 199 247
# 250 294
# 296 328
# 331 421
#   2% 2/97 [00:01<01:00,  1.58it/s]0 57
# 98 128
# 131 173
# 175 211
# 214 276
# 279 309
# 311 353
# 356 396
# 398 422
# 425 473
# 476 512
#   3% 3/97 [00:01<00:41,  2.25it/s]0 57
# 58 132
# 134 208
# 210 258
# 260 324
# 326 406
#   4% 4/97 [00:01<00:32,  2.83it/s]0 57
# 58 108
# 110 160
# 162 198
# 201 235
# 237 275
# 278 312
# 314 358
# 403 441
# 444 478
# 480 518
#   5% 5/97 [00:02<00:28,  3.28it/s]0 57
# 58 100
# 102 140
# 143 171
# 174 206
# 208 242
# 246 276
# 278 314
# 318 362
# 364 386
#   6% 6/97 [00:02<00:24,  3.65it/s]0 57
# 58 118
# 120 144
# 146 150
# 214 266
# 270 314
# 316 350
# 354 356
# 358 406
# 408 462
# 526 564
#   7% 7/97 [00:02<00:22,  3.92it/s]0 57
# 58 112
# 114 144
# 147 203
# 205 259
# 262 314
# 316 370
# 373 417
# 419 463
# 466 530
# 532 592
#   8% 8/97 [00:02<00:21,  4.11it/s]0 57
# 58 110
# 113 161
# 320 372
# 374 416
# 419 443
# 507 555
# 558 596
# 598 630
# 632 664
# 798 828
#  95% 126/132 [00:37<00:01,  3.35it/s]0 57
# 58 122
# 124 178
# 181 251
# 253 303
# 306 340
# 342 396
# 399 441
#  96% 127/132 [00:37<00:01,  3.64it/s]0 57
# 58 98
# 100 132
# 134 190
# 193 213
# 215 255
#  97% 128/132 [00:37<00:01,  3.90it/s]0 117
# 118 176
# 241 293
# 364 412
# 467 513
# 516 550
# 552 604
# 643 681
# 684 718
# 793 835
# 837 871
#  98% 129/132 [00:38<00:00,  3.90it/s]0 57
# 58 92
#  98% 130/132 [00:38<00:00,  4.12it/s]0 57
# 58 104
# 227 273
# 276 342
# 344 386
# 388 446
# 449 491
# 493 537
# 540 612
# 679 723
# 725 769
#  99% 131/132 [00:38<00:00,  4.05it/s]0 117
# 355 405
# 408 446
# 515 535
# 537 591
# 593 635
# 638 704
# 706 776
# 779 811
# 813 841
# 843 901
# 100% 132/132 [00:38<00:00,  3.40it/s]

# %% [markdown]
# ### Step 4A-qwen — released CRF/BMES head on Qwen features

# %%
# !python LIFE_train/train.py --split_dataset --data_path "{FEATURES_QWEN_BIN}" --train_path "{TRAIN_PATH_QWEN}" --test_path "{TEST_PATH_QWEN}" --model Transformer --num_train_epochs 50
# Out:
# Log INFO: split dataset...
# ********************************
# The overall data sources:
# ['MF_fake.jsonl', 'MR_true.jsonl']
# 100% 183/183 [00:00<00:00, 3632.69it/s]
# 100% 46/46 [00:00<00:00, 3253.15it/s]
#
# The number of train dataset: 183
# The number of test  dataset: 46
# ********************************
# 100% 183/183 [00:00<00:00, 749.02it/s]
# 100% 46/46 [00:00<00:00, 7603.17it/s]
# --------------------------------classify--------------------------------
# Log INFO: do train...
# Epoch:   0% 0/50 [00:00<?, ?it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:01<00:05,  1.18s/it]
# Iteration:  33% 2/6 [00:01<00:02,  1.78it/s]
# Iteration:  50% 3/6 [00:01<00:01,  2.73it/s]
# Iteration:  67% 4/6 [00:01<00:00,  3.74it/s]
# Iteration: 100% 6/6 [00:01<00:00,  3.40it/s]
# epoch 1: train_loss 2.7123603423436484
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  1.65it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.11it/s]
# ******** Evalation ********
# Accuracy: 51.7
# Macro F1 Score: 45.0
# Precision/Recall per class:
# 21.6/31.5 70.6/59.0
# ************************************************************************************************************************
# Epoch:   2% 1/50 [00:05<04:38,  5.69s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.26it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.58it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.58it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.05it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.54it/s]
# epoch 2: train_loss 2.6643391450246177
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.47it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.69it/s]
# ******** Evalation ********
# Accuracy: 53.2
# Macro F1 Score: 45.3
# Precision/Recall per class:
# 21.4/28.8 70.8/61.9
# ************************************************************************************************************************
# Epoch:   4% 2/50 [00:08<03:23,  4.24s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.57it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.61it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.74it/s]
# Iteration:  67% 4/6 [00:00<00:00,  7.99it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.63it/s]
# epoch 3: train_loss 2.6070404847462973
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.63it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.78it/s]
# ******** Evalation ********
# Accuracy: 56.5
# Macro F1 Score: 46.6
# Precision/Recall per class:
# 22.1/25.5 71.6/67.6
# ************************************************************************************************************************
# Epoch:   6% 3/50 [00:12<02:57,  3.77s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.88it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.69it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.75it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.14it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.58it/s]
# epoch 4: train_loss 2.4604583978652954
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.78it/s]
# ******** Evalation ********
# Accuracy: 59.1
# Macro F1 Score: 45.7
# Precision/Recall per class:
# 19.8/17.9 71.5/73.8
# ************************************************************************************************************************
# Epoch:   8% 4/50 [00:15<02:47,  3.64s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.82it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.89it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.03it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.33it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.69it/s]
# epoch 5: train_loss 2.3009031613667807
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.76it/s]
# ******** Evalation ********
# Accuracy: 66.7
# Macro F1 Score: 44.8
# Precision/Recall per class:
# 17.6/7.1 72.5/88.1
# ************************************************************************************************************************
# Epoch:  10% 5/50 [00:18<02:36,  3.48s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.77it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.77it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.79it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.19it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.60it/s]
# epoch 6: train_loss 2.114470442136129
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.63it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.79it/s]
# ******** Evalation ********
# Accuracy: 71.8
# Macro F1 Score: 42.3
# Precision/Recall per class:
# 7.1/0.5 73.2/97.5
# ************************************************************************************************************************
# Epoch:  12% 6/50 [00:21<02:28,  3.38s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.80it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.50it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.71it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.13it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.53it/s]
# epoch 7: train_loss 1.9399477640787761
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.61it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.79it/s]
# ******** Evalation ********
# Accuracy: 73.6
# Macro F1 Score: 42.4
# Precision/Recall per class:
# 0.0/0.0 73.6/100.0
# ************************************************************************************************************************
# Epoch:  14% 7/50 [00:25<02:26,  3.40s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.92it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.80it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.71it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.13it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.49it/s]
# epoch 8: train_loss 1.7886810501416524
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.61it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.78it/s]
# ******** Evalation ********
# Accuracy: 73.6
# Macro F1 Score: 42.4
# Precision/Recall per class:
# 0.0/0.0 73.6/100.0
# ************************************************************************************************************************
# Epoch:  16% 8/50 [00:28<02:19,  3.33s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.50it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.76it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.74it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.09it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.54it/s]
# epoch 9: train_loss 1.658885697523753
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.79it/s]
# ******** Evalation ********
# Accuracy: 73.6
# Macro F1 Score: 42.4
# Precision/Recall per class:
# 0.0/0.0 73.6/100.0
# ************************************************************************************************************************
# Epoch:  18% 9/50 [00:31<02:14,  3.29s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.95it/s]
# Iteration:  33% 2/6 [00:00<00:01,  3.96it/s]
# Iteration:  50% 3/6 [00:00<00:00,  5.09it/s]
# Iteration:  67% 4/6 [00:00<00:00,  6.06it/s]
# Iteration: 100% 6/6 [00:00<00:00,  6.54it/s]
# epoch 10: train_loss 1.5477669636408489
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.49it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.71it/s]
# ******** Evalation ********
# Accuracy: 73.6
# Macro F1 Score: 42.4
# Precision/Recall per class:
# 0.0/0.0 73.6/100.0
# ************************************************************************************************************************
# Epoch:  20% 10/50 [00:35<02:13,  3.34s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.52it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.79it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.77it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.06it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.54it/s]
# epoch 11: train_loss 1.4493515094121296
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.64it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.77it/s]
# ******** Evalation ********
# Accuracy: 72.7
# Macro F1 Score: 42.1
# Precision/Recall per class:
# 0.0/0.0 73.3/98.8
# ************************************************************************************************************************
# Epoch:  22% 11/50 [00:38<02:08,  3.29s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.79it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.85it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.05it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.27it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.65it/s]
# epoch 12: train_loss 1.3672634561856587
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.61it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.77it/s]
# ******** Evalation ********
# Accuracy: 69.3
# Macro F1 Score: 40.9
# Precision/Recall per class:
# 0.0/0.0 72.4/94.1
# ************************************************************************************************************************
# Epoch:  24% 12/50 [00:41<02:06,  3.33s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.80it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.79it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.01it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.32it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.76it/s]
# epoch 13: train_loss 1.2975003123283386
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.52it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.73it/s]
# ******** Evalation ********
# Accuracy: 61.5
# Macro F1 Score: 38.1
# Precision/Recall per class:
# 0.0/0.0 69.9/83.6
# ************************************************************************************************************************
# Epoch:  26% 13/50 [00:45<02:01,  3.29s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.75it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.77it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.14it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.36it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.77it/s]
# epoch 14: train_loss 1.2315853436787922
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.64it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.81it/s]
# ******** Evalation ********
# Accuracy: 60.3
# Macro F1 Score: 37.6
# Precision/Recall per class:
# 0.0/0.0 69.5/82.0
# ************************************************************************************************************************
# Epoch:  28% 14/50 [00:48<01:56,  3.25s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.75it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.69it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.16it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.35it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.71it/s]
# epoch 15: train_loss 1.1709572871526082
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.59it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.77it/s]
# ******** Evalation ********
# Accuracy: 55.5
# Macro F1 Score: 37.1
# Precision/Recall per class:
# 3.7/2.7 68.0/74.4
# ************************************************************************************************************************
# Epoch:  30% 15/50 [00:51<01:55,  3.31s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.59it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.66it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.15it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.34it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.75it/s]
# epoch 16: train_loss 1.1183048685391743
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.63it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.79it/s]
# ******** Evalation ********
# Accuracy: 55.5
# Macro F1 Score: 37.1
# Precision/Recall per class:
# 3.7/2.7 68.0/74.4
# ************************************************************************************************************************
# Epoch:  32% 16/50 [00:54<01:51,  3.27s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.87it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.75it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.92it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.05it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.53it/s]
# epoch 17: train_loss 1.0666139721870422
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.80it/s]
# ******** Evalation ********
# Accuracy: 53.3
# Macro F1 Score: 36.6
# Precision/Recall per class:
# 4.5/3.8 67.3/71.1
# ************************************************************************************************************************
# Epoch:  34% 17/50 [00:57<01:47,  3.25s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.64it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.82it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.73it/s]
# Iteration:  67% 4/6 [00:00<00:00,  7.77it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.47it/s]
# epoch 18: train_loss 1.0186357299486797
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.63it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.12it/s]
# ******** Evalation ********
# Accuracy: 56.2
# Macro F1 Score: 38.0
# Precision/Recall per class:
# 5.2/3.8 68.4/75.0
# ************************************************************************************************************************
# Epoch:  36% 18/50 [01:01<01:45,  3.30s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.96it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.79it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.04it/s]
# Iteration:  67% 4/6 [00:00<00:00,  7.92it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.57it/s]
# epoch 19: train_loss 0.9782844583193461
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.65it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.81it/s]
# ******** Evalation ********
# Accuracy: 60.3
# Macro F1 Score: 40.8
# Precision/Recall per class:
# 8.9/5.4 70.2/80.1
# ************************************************************************************************************************
# Epoch:  38% 19/50 [01:04<01:41,  3.27s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.57it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.77it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.90it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.21it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.59it/s]
# epoch 20: train_loss 0.9366481105486552
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.75it/s]
# ******** Evalation ********
# Accuracy: 70.0
# Macro F1 Score: 45.4
# Precision/Recall per class:
# 22.2/5.4 73.3/93.2
# ************************************************************************************************************************
# Epoch:  40% 20/50 [01:07<01:37,  3.25s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.67it/s]
# Iteration:  33% 2/6 [00:00<00:01,  3.88it/s]
# Iteration:  50% 3/6 [00:00<00:00,  4.94it/s]
# Iteration:  67% 4/6 [00:00<00:00,  5.74it/s]
# Iteration: 100% 6/6 [00:00<00:00,  6.38it/s]
# epoch 21: train_loss 0.9009361763795217
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.78it/s]
# ******** Evalation ********
# Accuracy: 71.8
# Macro F1 Score: 46.3
# Precision/Recall per class:
# 31.2/5.4 73.8/95.7
# ************************************************************************************************************************
# Epoch:  42% 21/50 [01:11<01:35,  3.31s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.69it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.75it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.91it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.03it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.57it/s]
# epoch 22: train_loss 0.8651562829812368
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.78it/s]
# ******** Evalation ********
# Accuracy: 71.8
# Macro F1 Score: 47.5
# Precision/Recall per class:
# 34.2/7.1 74.0/95.1
# ************************************************************************************************************************
# Epoch:  44% 22/50 [01:14<01:31,  3.27s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.63it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.55it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.85it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.10it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.62it/s]
# epoch 23: train_loss 0.8452054162820181
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.63it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.81it/s]
# ******** Evalation ********
# Accuracy: 73.6
# Macro F1 Score: 47.6
# Precision/Recall per class:
# 50.0/6.0 74.3/97.9
# ************************************************************************************************************************
# Epoch:  46% 23/50 [01:17<01:29,  3.32s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.48it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.51it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.93it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.25it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.52it/s]
# epoch 24: train_loss 0.8126238286495209
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.58it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.77it/s]
# ******** Evalation ********
# Accuracy: 74.7
# Macro F1 Score: 55.4
# Precision/Recall per class:
# 57.4/16.8 76.2/95.5
# ************************************************************************************************************************
# Epoch:  48% 24/50 [01:21<01:26,  3.32s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.69it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.90it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.37it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.46it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.74it/s]
# epoch 25: train_loss 0.7962527573108673
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.64it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.81it/s]
# ******** Evalation ********
# Accuracy: 79.6
# Macro F1 Score: 69.4
# Precision/Recall per class:
# 69.1/41.3 81.6/93.4
# ************************************************************************************************************************
# Epoch:  50% 25/50 [01:24<01:21,  3.27s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.63it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.69it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.07it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.36it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.71it/s]
# epoch 26: train_loss 0.7742353280385336
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.60it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.78it/s]
# ******** Evalation ********
# Accuracy: 79.6
# Macro F1 Score: 69.5
# Precision/Recall per class:
# 68.8/41.8 81.7/93.2
# ************************************************************************************************************************
# Epoch:  52% 26/50 [01:27<01:19,  3.32s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.49it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.73it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.15it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.35it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.68it/s]
# epoch 27: train_loss 0.7484278678894043
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.59it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.76it/s]
# ******** Evalation ********
# Accuracy: 83.0
# Macro F1 Score: 76.7
# Precision/Recall per class:
# 72.3/58.2 85.9/92.0
# ************************************************************************************************************************
# Epoch:  54% 27/50 [01:31<01:15,  3.29s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.56it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.67it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.21it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.39it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.74it/s]
# epoch 28: train_loss 0.7351843317349752
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.63it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.80it/s]
# ******** Evalation ********
# Accuracy: 83.2
# Macro F1 Score: 77.1
# Precision/Recall per class:
# 71.9/59.8 86.4/91.6
# ************************************************************************************************************************
# Epoch:  56% 28/50 [01:34<01:11,  3.26s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.56it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.68it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.00it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.20it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.67it/s]
# epoch 29: train_loss 0.7297327717145284
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.12it/s]
# ******** Evalation ********
# Accuracy: 82.2
# Macro F1 Score: 75.3
# Precision/Recall per class:
# 70.8/55.4 85.1/91.8
# ************************************************************************************************************************
# Epoch:  58% 29/50 [01:37<01:09,  3.30s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.63it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.53it/s]
# Iteration:  50% 3/6 [00:00<00:00,  7.71it/s]
# Iteration:  67% 4/6 [00:00<00:00,  7.81it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.41it/s]
# epoch 30: train_loss 0.7115419308344523
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.60it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.77it/s]
# ******** Evalation ********
# Accuracy: 83.2
# Macro F1 Score: 77.0
# Precision/Recall per class:
# 72.2/59.2 86.2/91.8
# ************************************************************************************************************************
# Epoch:  60% 30/50 [01:40<01:05,  3.29s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.89it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.55it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.13it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.34it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.67it/s]
# epoch 31: train_loss 0.693122794230779
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.59it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.74it/s]
# ******** Evalation ********
# Accuracy: 84.1
# Macro F1 Score: 78.4
# Precision/Recall per class:
# 73.2/62.5 87.2/91.8
# ************************************************************************************************************************
# Epoch:  62% 31/50 [01:44<01:02,  3.27s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.74it/s]
# Iteration:  33% 2/6 [00:00<00:01,  3.87it/s]
# Iteration:  50% 3/6 [00:00<00:00,  5.02it/s]
# Iteration:  67% 4/6 [00:00<00:00,  5.92it/s]
# Iteration: 100% 6/6 [00:00<00:00,  6.39it/s]
# epoch 32: train_loss 0.6793677012125651
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.65it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.81it/s]
# ******** Evalation ********
# Accuracy: 84.1
# Macro F1 Score: 78.4
# Precision/Recall per class:
# 73.2/62.5 87.2/91.8
# ************************************************************************************************************************
# Epoch:  64% 32/50 [01:47<00:59,  3.32s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.72it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.73it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.19it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.38it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.76it/s]
# epoch 33: train_loss 0.6631899575392405
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.77it/s]
# ******** Evalation ********
# Accuracy: 84.1
# Macro F1 Score: 78.4
# Precision/Recall per class:
# 73.2/62.5 87.2/91.8
# ************************************************************************************************************************
# Epoch:  66% 33/50 [01:50<00:55,  3.29s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.82it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.67it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8
/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  7.85it/s]
# Iteration:  33% 2/6 [00:00<00:00,  7.99it/s]
# Iteration:  50% 3/6 [00:00<00:00,  8.41it/s]
# Iteration:  67% 4/6 [00:00<00:00,  8.56it/s]
# Iteration: 100% 6/6 [00:00<00:00,  8.77it/s]
# epoch 50: train_loss 0.5722670058409373
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration:  50% 1/2 [00:00<00:00,  2.62it/s]
# Iteration: 100% 2/2 [00:00<00:00,  2.78it/s]
# ******** Evalation ********
# Accuracy: 83.9
# Macro F1 Score: 78.2
# Precision/Recall per class:
# 73.1/62.0 87.0/91.8
# ************************************************************************************************************************
# Epoch: 100% 50/50 [02:46<00:00,  3.34s/it]

# %% [markdown]
# ### Step 4B-qwen — paper BCE head on Qwen features
# Same Qwen features + deterministic seed-0 split as 4A. Sweep `--seed 1..20` for mean+-std.

# %%
# !python LIFE_train/train_bce.py --split_dataset --data_path "{FEATURES_QWEN_BIN}" --train_path "{TRAIN_PATH_QWEN}" --test_path "{TEST_PATH_QWEN}" --num_train_epochs 50 --seed 20
# Out:
# Log INFO: split dataset...
# ********************************
# The overall data sources:
# ['MF_fake.jsonl', 'MR_true.jsonl']
# 100% 183/183 [00:00<00:00, 3745.63it/s]
# 100% 46/46 [00:00<00:00, 3438.87it/s]
#
# The number of train dataset: 183
# The number of test  dataset: 46
# ********************************
# 100% 183/183 [00:00<00:00, 7217.01it/s]
# 100% 46/46 [00:00<00:00, 6974.33it/s]
# seed: 20
# --------------------------------BCE head (paper Eq 11-12)--------------------------------
# Log INFO: do train...
# Epoch:   0% 0/50 [00:00<?, ?it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:02,  1.70it/s]
# Iteration:  33% 2/6 [00:00<00:01,  3.27it/s]
# Iteration:  50% 3/6 [00:00<00:00,  4.67it/s]
# Iteration:  67% 4/6 [00:00<00:00,  5.79it/s]
# Iteration: 100% 6/6 [00:01<00:00,  5.48it/s]
# epoch 1: train_loss 0.7063817282517751
#
# Iteration:   0% 0/2 [00:00<?, ?it/s]
# Iteration: 100% 2/2 [00:00<00:00, 13.50it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:   2% 1/50 [00:01<01:02,  1.28s/it]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.05it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.04it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.53it/s]
# epoch 2: train_loss 0.6940315365791321
#
# Iteration: 100% 2/2 [00:00<00:00, 25.28it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:   4% 2/50 [00:01<00:44,  1.08it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.23it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.98it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.52it/s]
# epoch 3: train_loss 0.6933411260445913
#
# Iteration: 100% 2/2 [00:00<00:00, 25.22it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:   6% 3/50 [00:02<00:38,  1.23it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.77it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.89it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.98it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.51it/s]
# epoch 4: train_loss 0.6833001871903738
#
# Iteration: 100% 2/2 [00:00<00:00, 24.81it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:   8% 4/50 [00:03<00:35,  1.31it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.98it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.95it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.07it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.48it/s]
# epoch 5: train_loss 0.677815447251002
#
# Iteration: 100% 2/2 [00:00<00:00, 25.11it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:  10% 5/50 [00:04<00:33,  1.36it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.09it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.02it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.48it/s]
# epoch 6: train_loss 0.6648786664009094
#
# Iteration: 100% 2/2 [00:00<00:00, 25.21it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:  12% 6/50 [00:04<00:31,  1.39it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.99it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.08it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.49it/s]
# epoch 7: train_loss 0.6679114798704783
#
# Iteration: 100% 2/2 [00:00<00:00, 25.17it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:  14% 7/50 [00:05<00:30,  1.41it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.85it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.97it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.44it/s]
# epoch 8: train_loss 0.6681446433067322
#
# Iteration: 100% 2/2 [00:00<00:00, 25.11it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:  16% 8/50 [00:06<00:29,  1.43it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.99it/s]
# Iteration:  50% 3/6 [00:00<00:00, 10.10it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.44it/s]
# epoch 9: train_loss 0.6582023203372955
#
# Iteration: 100% 2/2 [00:00<00:00, 24.64it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:  18% 9/50 [00:06<00:28,  1.44it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.06it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.96it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.46it/s]
# epoch 10: train_loss 0.6487580339113871
#
# Iteration: 100% 2/2 [00:00<00:00, 24.95it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:  20% 10/50 [00:07<00:27,  1.44it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.85it/s]
# Iteration:  50% 3/6 [00:00<00:00, 10.01it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.42it/s]
# epoch 11: train_loss 0.6383503973484039
#
# Iteration: 100% 2/2 [00:00<00:00, 25.28it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:  22% 11/50 [00:08<00:26,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.24it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.42it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.66it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.27it/s]
# epoch 12: train_loss 0.6302138864994049
#
# Iteration: 100% 2/2 [00:00<00:00, 25.09it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:  24% 12/50 [00:08<00:26,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.98it/s]
# Iteration:  50% 3/6 [00:00<00:00, 10.04it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.47it/s]
# epoch 13: train_loss 0.6232498188813528
#
# Iteration: 100% 2/2 [00:00<00:00, 24.96it/s]
# ******** Evalation ********
# Accuracy: 63.0
# Macro F1 Score: 38.7
# Precision/Recall per class (real=0, fake=1):
# 63.0/100.0 0.0/0.0
# ************************************************************************************************************************
# Epoch:  26% 13/50 [00:09<00:25,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.12it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.99it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.49it/s]
# epoch 14: train_loss 0.6124104658762614
#
# Iteration: 100% 2/2 [00:00<00:00, 25.09it/s]
# ******** Evalation ********
# Accuracy: 65.2
# Macro F1 Score: 44.7
# Precision/Recall per class (real=0, fake=1):
# 64.4/100.0 100.0/5.9
# ************************************************************************************************************************
# Epoch:  28% 14/50 [00:10<00:24,  1.46it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.19it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.98it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.48it/s]
# epoch 15: train_loss 0.6105141838391622
#
# Iteration: 100% 2/2 [00:00<00:00, 24.70it/s]
# ******** Evalation ********
# Accuracy: 67.4
# Macro F1 Score: 50.3
# Precision/Recall per class (real=0, fake=1):
# 65.9/100.0 100.0/11.8
# ************************************************************************************************************************
# Epoch:  30% 15/50 [00:10<00:23,  1.46it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.04it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.02it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.47it/s]
# epoch 16: train_loss 0.5955610275268555
#
# Iteration: 100% 2/2 [00:00<00:00, 25.04it/s]
# ******** Evalation ********
# Accuracy: 71.7
# Macro F1 Score: 59.9
# Precision/Recall per class (real=0, fake=1):
# 69.0/100.0 100.0/23.5
# ************************************************************************************************************************
# Epoch:  32% 16/50 [00:11<00:23,  1.46it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.01it/s]
# Iteration:  67% 4/6 [00:00<00:00,  6.07it/s]
# Iteration: 100% 6/6 [00:00<00:00,  7.57it/s]
# epoch 17: train_loss 0.5940920313199362
#
# Iteration: 100% 2/2 [00:00<00:00, 24.98it/s]
# ******** Evalation ********
# Accuracy: 78.3
# Macro F1 Score: 71.8
# Precision/Recall per class (real=0, fake=1):
# 74.4/100.0 100.0/41.2
# ************************************************************************************************************************
# Epoch:  34% 17/50 [00:12<00:24,  1.33it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.92it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.97it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.44it/s]
# epoch 18: train_loss 0.5825490554173788
#
# Iteration: 100% 2/2 [00:00<00:00, 25.24it/s]
# ******** Evalation ********
# Accuracy: 78.3
# Macro F1 Score: 71.8
# Precision/Recall per class (real=0, fake=1):
# 74.4/100.0 100.0/41.2
# ************************************************************************************************************************
# Epoch:  36% 18/50 [00:13<00:23,  1.36it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.09it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.00it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.43it/s]
# epoch 19: train_loss 0.5704147517681122
#
# Iteration: 100% 2/2 [00:00<00:00, 25.06it/s]
# ******** Evalation ********
# Accuracy: 78.3
# Macro F1 Score: 71.8
# Precision/Recall per class (real=0, fake=1):
# 74.4/100.0 100.0/41.2
# ************************************************************************************************************************
# Epoch:  38% 19/50 [00:13<00:22,  1.39it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.82it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.90it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.40it/s]
# epoch 20: train_loss 0.5612662434577942
#
# Iteration: 100% 2/2 [00:00<00:00, 24.74it/s]
# ******** Evalation ********
# Accuracy: 78.3
# Macro F1 Score: 71.8
# Precision/Recall per class (real=0, fake=1):
# 74.4/100.0 100.0/41.2
# ************************************************************************************************************************
# Epoch:  40% 20/50 [00:14<00:21,  1.41it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.75it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.96it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.97it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.42it/s]
# epoch 21: train_loss 0.5574827293554941
#
# Iteration: 100% 2/2 [00:00<00:00, 25.02it/s]
# ******** Evalation ********
# Accuracy: 82.6
# Macro F1 Score: 78.6
# Precision/Recall per class (real=0, fake=1):
# 78.4/100.0 100.0/52.9
# ************************************************************************************************************************
# Epoch:  42% 21/50 [00:15<00:20,  1.42it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.78it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.96it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.90it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.41it/s]
# epoch 22: train_loss 0.5483707388242086
#
# Iteration: 100% 2/2 [00:00<00:00, 24.68it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  44% 22/50 [00:15<00:19,  1.43it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.82it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.97it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.39it/s]
# epoch 23: train_loss 0.543145219484965
#
# Iteration: 100% 2/2 [00:00<00:00, 25.07it/s]
# ******** Evalation ********
# Accuracy: 84.8
# Macro F1 Score: 81.7
# Precision/Recall per class (real=0, fake=1):
# 80.6/100.0 100.0/58.8
# ************************************************************************************************************************
# Epoch:  46% 23/50 [00:16<00:18,  1.44it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.84it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.89it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.41it/s]
# epoch 24: train_loss 0.5256843666235606
#
# Iteration: 100% 2/2 [00:00<00:00, 25.05it/s]
# ******** Evalation ********
# Accuracy: 82.6
# Macro F1 Score: 78.6
# Precision/Recall per class (real=0, fake=1):
# 78.4/100.0 100.0/52.9
# ************************************************************************************************************************
# Epoch:  48% 24/50 [00:17<00:17,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.05it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.92it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.41it/s]
# epoch 25: train_loss 0.520550936460495
#
# Iteration: 100% 2/2 [00:00<00:00, 24.86it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  50% 25/50 [00:17<00:17,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.81it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.87it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.81it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.39it/s]
# epoch 26: train_loss 0.5101245443026224
#
# Iteration: 100% 2/2 [00:00<00:00, 24.82it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  52% 26/50 [00:18<00:16,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.92it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.90it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.94it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.89it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.39it/s]
# epoch 27: train_loss 0.49797114233175915
#
# Iteration: 100% 2/2 [00:00<00:00, 25.02it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  54% 27/50 [00:19<00:15,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.04it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.02it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.44it/s]
# epoch 28: train_loss 0.496022825439771
#
# Iteration: 100% 2/2 [00:00<00:00, 24.89it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  56% 28/50 [00:20<00:15,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.97it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.93it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.91it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.35it/s]
# epoch 29: train_loss 0.49804147084554035
#
# Iteration: 100% 2/2 [00:00<00:00, 25.09it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  58% 29/50 [00:20<00:14,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.90it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.80it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.80it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.87it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.30it/s]
# epoch 30: train_loss 0.4868033826351166
#
# Iteration: 100% 2/2 [00:00<00:00, 24.61it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  60% 30/50 [00:21<00:13,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.88it/s]
# Iteration:  50% 3/6 [00:00<00:00, 10.03it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.96it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.38it/s]
# epoch 31: train_loss 0.4776841898759206
#
# Iteration: 100% 2/2 [00:00<00:00, 24.89it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  62% 31/50 [00:22<00:13,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.89it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.74it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.83it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.42it/s]
# epoch 32: train_loss 0.4730294346809387
#
# Iteration: 100% 2/2 [00:00<00:00, 24.92it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  64% 32/50 [00:22<00:12,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.93it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.00it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.42it/s]
# epoch 33: train_loss 0.4695174992084503
#
# Iteration: 100% 2/2 [00:00<00:00, 24.64it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  66% 33/50 [00:23<00:11,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.90it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.97it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.44it/s]
# epoch 34: train_loss 0.4738016327222188
#
# Iteration: 100% 2/2 [00:00<00:00, 25.15it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  68% 34/50 [00:24<00:11,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00, 10.02it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.95it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.44it/s]
# epoch 35: train_loss 0.46680469810962677
#
# Iteration: 100% 2/2 [00:00<00:00, 25.04it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  70% 35/50 [00:24<00:10,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.61it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.99it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.41it/s]
# epoch 36: train_loss 0.45766598482926685
#
# Iteration: 100% 2/2 [00:00<00:00, 24.95it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  72% 36/50 [00:25<00:09,  1.46it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.39it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.86it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.87it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.31it/s]
# epoch 37: train_loss 0.4561072687307994
#
# Iteration: 100% 2/2 [00:00<00:00, 24.94it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  74% 37/50 [00:26<00:08,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.86it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.89it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.84it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.90it/s]
# Iteration: 100% 6/6 [00:00<00:00,  7.51it/s]
# epoch 38: train_loss 0.4473520865043004
#
# Iteration: 100% 2/2 [00:00<00:00, 24.55it/s]
# ******** Evalation ********
# Accuracy: 84.8
# Macro F1 Score: 82.4
# Precision/Recall per class (real=0, fake=1):
# 82.4/96.6 91.7/64.7
# ************************************************************************************************************************
# Epoch:  76% 38/50 [00:27<00:09,  1.32it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.67it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.84it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.97it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.36it/s]
# epoch 39: train_loss 0.44741963346799213
#
# Iteration: 100% 2/2 [00:00<00:00, 24.88it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  78% 39/50 [00:27<00:08,  1.36it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.59it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.94it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.87it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.39it/s]
# epoch 40: train_loss 0.4555029074350993
#
# Iteration: 100% 2/2 [00:00<00:00, 24.88it/s]
# ******** Evalation ********
# Accuracy: 84.8
# Macro F1 Score: 82.4
# Precision/Recall per class (real=0, fake=1):
# 82.4/96.6 91.7/64.7
# ************************************************************************************************************************
# Epoch:  80% 40/50 [00:28<00:07,  1.39it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.96it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.97it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.05it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.44it/s]
# epoch 41: train_loss 0.43535958727200824
#
# Iteration: 100% 2/2 [00:00<00:00, 24.63it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  82% 41/50 [00:29<00:06,  1.41it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.91it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.95it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.41it/s]
# epoch 42: train_loss 0.4481598337491353
#
# Iteration: 100% 2/2 [00:00<00:00, 25.14it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 84.6
# Precision/Recall per class (real=0, fake=1):
# 82.9/100.0 100.0/64.7
# ************************************************************************************************************************
# Epoch:  84% 42/50 [00:29<00:05,  1.42it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.98it/s]
# Iteration:  67% 4/6 [00:00<00:00, 10.03it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.43it/s]
# epoch 43: train_loss 0.4386838773886363
#
# Iteration: 100% 2/2 [00:00<00:00, 24.99it/s]
# ******** Evalation ********
# Accuracy: 84.8
# Macro F1 Score: 82.4
# Precision/Recall per class (real=0, fake=1):
# 82.4/96.6 91.7/64.7
# ************************************************************************************************************************
# Epoch:  86% 43/50 [00:30<00:04,  1.43it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.65it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.73it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.96it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.38it/s]
# epoch 44: train_loss 0.43909473220507306
#
# Iteration: 100% 2/2 [00:00<00:00, 24.80it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  88% 44/50 [00:31<00:04,  1.44it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.81it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.91it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.88it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.86it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.36it/s]
# epoch 45: train_loss 0.4410423735777537
#
# Iteration: 100% 2/2 [00:00<00:00, 24.64it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  90% 45/50 [00:31<00:03,  1.44it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.98it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.87it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.80it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.38it/s]
# epoch 46: train_loss 0.4406384378671646
#
# Iteration: 100% 2/2 [00:00<00:00, 24.74it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  92% 46/50 [00:32<00:02,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.96it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.90it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.93it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.35it/s]
# epoch 47: train_loss 0.4369094669818878
#
# Iteration: 100% 2/2 [00:00<00:00, 24.54it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  94% 47/50 [00:33<00:02,  1.44it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.97it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.87it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.81it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.85it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.38it/s]
# epoch 48: train_loss 0.43595809241135913
#
# Iteration: 100% 2/2 [00:00<00:00, 25.19it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  96% 48/50 [00:34<00:01,  1.44it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  17% 1/6 [00:00<00:00,  9.97it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.88it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.89it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.91it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.40it/s]
# epoch 49: train_loss 0.43239277601242065
#
# Iteration: 100% 2/2 [00:00<00:00, 24.95it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch:  98% 49/50 [00:34<00:00,  1.45it/s]
# Iteration:   0% 0/6 [00:00<?, ?it/s]
# Iteration:  33% 2/6 [00:00<00:00,  9.96it/s]
# Iteration:  50% 3/6 [00:00<00:00,  9.96it/s]
# Iteration:  67% 4/6 [00:00<00:00,  9.95it/s]
# Iteration: 100% 6/6 [00:00<00:00, 10.43it/s]
# epoch 50: train_loss 0.4321209987004598
#
# Iteration: 100% 2/2 [00:00<00:00, 24.96it/s]
# ******** Evalation ********
# Accuracy: 87.0
# Macro F1 Score: 85.2
# Precision/Recall per class (real=0, fake=1):
# 84.8/96.6 92.3/70.6
# ************************************************************************************************************************
# Epoch: 100% 50/50 [00:35<00:00,  1.41it/s]

# %% [markdown]
# ## Notes / troubleshooting
# - **HF gating**: Step 3 defaults to the ungated `NousResearch/Llama-2-7b-hf` mirror (no token). If you switch to the official `meta-llama` repo and hit a 403 "gated repo", your access request hasn't been approved yet.
# - **fastNLP**: if Step 4 errors on `from fastNLP.modules.torch import ...`, run `!pip install -q fastNLP==1.0.1` and restart the runtime.
# - **Checkpoints**: `BERT_CKPT` (step 1) and `linear_en.pt` (step 4) are written under `PROJECT_DIR` on Drive, so they survive disconnects.
# - **NaN features**: if Step 3 prints NaN/inf, switch Step 3 to `--dtype float32` (fits the 40 GB A100).
# - **Re-runs**: Step 2 mutates `OUTPUT_BIN` in place; always re-run Step 0 before re-running Steps 1–3 from scratch.
